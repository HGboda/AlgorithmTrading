# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../../custom.css", "r").read()
    return HTML(styles)

css_styling()
# Out:
# <style>
#     #notebook_panel { /* main background */
#     background: #333;
#     color: #f6f6f6;
# }
#
# div #notebook { /* centre the content */
#     background: #fff;
#     color: #333;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     padding-top: 2ex;
# }
#
# /* remove big margins around title */
# div.text_cell_render.border-box-sizing.rendered_html {
#     margin: 0;
#     padding: 0;
#     margin-left: 1ex;
# }
# div.cell.text_cell.border-box-sizing {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h1 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h2 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h3 {
#     margin: 0;
#     padding: 0;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 100%;
#
# }
#
# div.cell.code_cell { /* area that contains code + output */
#     background: #fff;
#     border: none;
#     border-radius: 10px;
#     padding-top: 1ex;
#
# }
#
# div.input_area { /* box around box with code */
#     border: none;
#     background: #f5f5f5;
#     border: 1px solid #ccc;
#     border-radius: 10px;
#     padding-top: 0.5ex;
#     padding-bottom: 0.5ex;
#     padding-left: 0.5em;
# }
#
# div.input { /* box with code */
# }
#
# div.CodeMirror { /* code font */
#     font-family: "Inconsolata-dz", monospace;
#     font-size: 10pt;
# }
#
# div.prompt { /* remove In/Out prompt */
#     display: none;
# }
#
# div.output_subarea { /* remove margin in front of output */
#     border: none;
# }
#
# div.cell.border-box-sizing.code_cell.running {
#     /* draw border around running cells */
#     border: 3px dotted #f33;
# }
#
# /* header colours and fonts */
# h1 { color: #444; }
# h2 { color: #444; }
# h3 { color: #444; font-style: italic; font-weight: normal}
#
#
# table.dataframe {
# font-size:80%;
# width:100%;
# }
#
#
# .debugtb1
# {
#     font-family: "Lucida Sans Unicode", "Lucida Grande", Sans-Serif;
#     font-size: 11px;
#     /*margin: 45px;*/
#     /*width: 480px;*/
#     margin: 1%;
#     width: 100%;
#     text-align: left;
#     border-collapse: collapse;
# }
# .debugtb1 th
# {
#     font-size: 11px;
#     font-weight: normal;
#     padding: 8px;
#     background: #b9c9fe;
#     border-top: 4px solid #aabcfe;
#     border-bottom: 1px solid #fff;
#     color: #039;
# }
# .debugtb1 td
# {
#     padding: 8px;
#     background: #e8edff;
#     border-bottom: 1px solid #fff;
#     color: #669;
#     border-top: 1px solid transparent;
# }
# .debugtb1 tr:hover td
# {
#     background: #d0dafd;
#     color: #339;
# }
#
# .debugtb2
# {
#     font-family: "Lucida Sans Unicode", "Lucida Grande", Sans-Serif;
#     font-size: 12px;
#     margin: 45px;
#     width: 480px;
#     text-align: center;
#     border-collapse: collapse;
#     border-top: 7px solid #9baff1;
#     border-bottom: 7px solid #9baff1;
# }
# .debugtb2 th
# {
#     font-size: 13px;
#     font-weight: normal;
#     padding: 8px;
#     background: #e8edff;
#     border-right: 1px solid #9baff1;
#     border-left: 1px solid #9baff1;
#     color: #039;
# }
# .debugtb2 td
# {
#     padding: 8px;
#     background: #e8edff;
#     border-right: 1px solid #aabcfe;
#     border-left: 1px solid #aabcfe;
#     color: #669;
# }
# </style>

# %%
import sys
sys.path.append('../../src/main/')
sys.path.append('../../lib/')

# %reload_ext autoreload
# %autoreload 
from stockcore import *
from tradingalgo import *
from data_mani import *

# %run ../../src/main/scrap.py  

# %matplotlib inline
pd.set_option('display.width',500)
import scrap as sc

sctype = 5
textouts = sc.getData(sctype)

results = pd.DataFrame({'title':textouts})
results = results.drop_duplicates('title')
results = results.reset_index()
results = results.drop('index',1)
dbfilename = 'naver_00'
tableName = 'naver_00'
sc.saveData(results,dbfilename,tableName)

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0 </th>
#       <td>      코나아이</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td>      오르비텍</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td>    BGF리테일</td>
#     </tr>
#     <tr>
#       <th>3 </th>
#       <td>    한국항공우주</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td>      현대통신</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td>    LG하우시스</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td>    LG유플러스</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td>   한국사이버결제</td>
#     </tr>
#     <tr>
#       <th>8 </th>
#       <td>       KCI</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td>      강원랜드</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>        디오</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>        한섬</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>      한국전력</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>    LG생활건강</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>    SK C&amp;C</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>     엔씨소프트</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>       현대차</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>     동부하이텍</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>        동서</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>        농심</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>       MPK</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>     유비벨록스</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>    에스앤에스텍</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>    씨티씨바이오</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>      현대산업</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>        한샘</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>    코오롱글로벌</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>       이마트</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>        CJ</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>       휴비츠</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>      코스맥스</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>     현대백화점</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>       KCC</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>    KT서브마린</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>      유한양행</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>   세이브존I&amp;C</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>    아모레퍼시픽</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>    한국금융지주</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>    JB금융지주</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>      매일유업</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td> NHN엔터테인먼트</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>      삼성화재</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>     SK케미칼</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>     동아에스티</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>      삼성전자</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>    CJ제일제당</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>     S-Oil</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>    CJ CGV</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>     삼양제넥스</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>       종근당</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>      고려아연</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>     롯데케미칼</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>       인탑스</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>    SK하이닉스</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>      현대제철</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>     농우바이오</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>      한미약품</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>        무학</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>    롯데하이마트</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>     바이오랜드</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>      하나투어</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>     조광페인트</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>        대교</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>    에프엔씨엔터</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>     AK홀딩스</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>      KT&amp;G</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>     신세계푸드</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>     MDS테크</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>     현대홈쇼핑</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>    에리트베이직</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>     넥센타이어</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>       에스원</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>    한글과컴퓨터</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>       코웨이</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>      국도화학</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>    한국정보인증</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>       오리온</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>    LG생명과학</td>
#     </tr>
#   </tbody>
# </table>

# %%
import sys
sys.path.append('../../src/main/')
sys.path.append('../../lib/')

# %reload_ext autoreload
# %autoreload 
from stockcore import *
from tradingalgo import *
from data_mani import *

# %run ../../src/main/scrap.py  

# %matplotlib inline
pd.set_option('display.width',500)
import scrap as sc

sctype = 1
textouts = sc.getData(sctype)

results = pd.DataFrame({'title':textouts})
results = results.drop_duplicates('title')
results = results.reset_index()
results = results.drop('index',1)

dbfilename = 'paxnet_00'
tableName = 'paxnet_00'
sc.saveData(results,dbfilename,tableName)

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0 </th>
#       <td>    호텔신라</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td>   AP시스템</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td>    한국전력</td>
#     </tr>
#     <tr>
#       <th>3 </th>
#       <td>  BGF리테일</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td>     네패스</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td>      효성</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td>      E1</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td>    삼성전자</td>
#     </tr>
#     <tr>
#       <th>8 </th>
#       <td>  SK하이닉스</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td>   케이피에프</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>  이코리아리츠</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>   승화프리텍</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>    사조해표</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>  데브시스터즈</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>     씨큐브</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>    서원인텍</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>      대현</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>    아이원스</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>  서화정보통신</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>     뉴인텍</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>     디젠스</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>   쎌바이오텍</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>    메디톡스</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>    아이리버</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>   유양디앤유</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td> 삼기오토모티브</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>   바이오랜드</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>    금호산업</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>    우리기술</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>    네오티스</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>   세종텔레콤</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>     이니텍</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>    세아제강</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>    용현BM</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>    백광산업</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>  글로벌에스엠</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>   삼양홀딩스</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>    남양유업</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>   엠벤처투자</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>     와이솔</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>   씨에스윈드</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>    대한전선</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>   다음카카오</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>    대우증권</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>    이스타코</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>    이구산업</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>     바른손</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>   메리츠화재</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>   동아에스텍</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>   대진디엠피</td>
#     </tr>
#   </tbody>
# </table>

# %%
import sys
sys.path.append('../../src/main/')
sys.path.append('../../lib/')

# %reload_ext autoreload
# %autoreload 
from stockcore import *
from tradingalgo import *
from data_mani import *

# %run ../../src/main/scrap.py  

# %matplotlib inline
pd.set_option('display.width',500)
import scrap as sc

sctype = 2
textouts = sc.getData(sctype)

results = pd.DataFrame({'title':textouts})
results = results.drop_duplicates('title')
results = results.reset_index()
results = results.drop('index',1)

dbfilename = 'paxnet_01'
tableName = 'paxnet_01'
sc.saveData(results,dbfilename,tableName)

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0 </th>
#       <td>    파미셀</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td>   대화제약</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td>    위지트</td>
#     </tr>
#     <tr>
#       <th>3 </th>
#       <td> 케이디미디어</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td>   레드로버</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td> 대우조선해양</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td>    코미팜</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td> 액토즈소프트</td>
#     </tr>
#     <tr>
#       <th>8 </th>
#       <td>   위메이드</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td> SK하이닉스</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>  수산중공업</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>  에이치엘비</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>   한진해운</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>   네이처셀</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td> 슈넬생명과학</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>   아남전자</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>    인터엠</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>   셀트리온</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>    현대차</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>   아이에이</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>     상보</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td> JW중외제약</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>   디지아이</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>  JW홀딩스</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>    휴온스</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>   일동제약</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>   삼성물산</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>   대한뉴팜</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td> 현대아이비티</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>    엠피씨</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>   원풍물산</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>   홈캐스트</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>    큐로컴</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>    팬오션</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>    헤스본</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td> 참엔지니어링</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>   엠씨넥스</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>    젬백스</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>   LG전자</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>   일양약품</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>   트레이스</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>  비츠로시스</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>   현대상선</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>  바이로메드</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td> 대명코퍼레이</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>   삼지전자</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td> 성창기업지주</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>   나노엔텍</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>  세원셀론텍</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>   케이엘티</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td> 한올바이오파</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>  CMG제약</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>    썬코어</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>   한미약품</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>    OCI</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>   대원전선</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>   유비쿼스</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>    넥솔론</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>  삼성중공업</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>  옴니시스템</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>     솔본</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td> 한미사이언스</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>  제이엠아이</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td> 아미노로직스</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>   동양물산</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>   일성건설</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>  메디포스트</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>  차바이오텍</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>  S-Oil</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>   일신석재</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>    엔케이</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td> 페이퍼코리아</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>  룽투코리아</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>   범양건영</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>  현대페인트</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>  서울반도체</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td> JW중외신약</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>   마크로젠</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td> 이스트소프트</td>
#     </tr>
#   </tbody>
# </table>

# %%
import sys
sys.path.append('../../src/main/')
sys.path.append('../../lib/')

# %reload_ext autoreload
# %autoreload 
from stockcore import *
from tradingalgo import *
from data_mani import *

# %run ../../src/main/scrap.py  

# %matplotlib inline
pd.set_option('display.width',500)
import scrap as sc

sctype = 3
textouts = sc.getData(sctype)

results = pd.DataFrame({'title':textouts})
results = results.drop_duplicates('title')
results = results.reset_index()
results = results.drop('index',1)

dbfilename = 'paxnet_02'
tableName = 'paxnet_02'
sc.saveData(results,dbfilename,tableName)

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0 </th>
#       <td>       케이엘티</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td>         원익</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td>       구영테크</td>
#     </tr>
#     <tr>
#       <th>3 </th>
#       <td>       휴바이론</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td>       서원인텍</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td>      플레이위드</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td>  NHN엔터테인먼트</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td>       현대위아</td>
#     </tr>
#     <tr>
#       <th>8 </th>
#       <td>      효성ITX</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td>       이스타코</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>      옴니시스템</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>      KR모터스</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>     대신정보통신</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>      스포츠서울</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>         3S</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td> 인테그레이티드에너지</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>     일경산업개발</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>    SK네트웍스우</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>      지어소프트</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>      나라엠앤디</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>       이아이디</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>     웰메이드예당</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>       세아제강</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>  JW중외제약2우B</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>     성창기업지주</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>       모베이스</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>        신원우</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>      진매트릭스</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>     케이디미디어</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>        휴비스</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>      태평양물산</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>      모바일리더</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>         코원</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>  파마리서치프로덕트</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>      조일알미늄</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>       한진해운</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>       유지인트</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>         국보</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>    아이쓰리시스템</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>      CMG제약</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>     한익스프레스</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>       주연테크</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>       아큐픽스</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>      쌍용양회우</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>     NH투자증권</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>    한스바이오메드</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>     액토즈소프트</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>      진바이오텍</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>        체시스</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>     오리엔트정공</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>      아시아경제</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>       대동스틸</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>    에스아이리소스</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>     베트남개발1</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>        엔케이</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>       레드로버</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>        팬오션</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>        뉴보텍</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>        디아이</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>     현대정보기술</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>       팜스토리</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>        레이젠</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>      삼성중공우</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>      수산중공업</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>       유성기업</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>        아티스</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>        부스타</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>        쌍방울</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>       코나아이</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>  하나머스트3호스팩</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>        펩트론</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>        코아스</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>       삼성물산</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>       신풍제지</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>    흥국화재2우B</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>      티에이치엔</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>       일성건설</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>     드래곤플라이</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>       이미지스</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>    한국전자홀딩스</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>     팜스웰바이오</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>      태영건설우</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>      케이디건설</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>       다우기술</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>       바이넥스</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>        이니텍</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>     현대아이비티</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>      레드캡투어</td>
#     </tr>
#     <tr>
#       <th>88</th>
#       <td>    쌍용양회3우B</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>    동원시스템즈우</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>      금호산업우</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>       제룡산업</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>         엠젠</td>
#     </tr>
#     <tr>
#       <th>93</th>
#       <td>       조아제약</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>      한솔PNS</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>       플랜티넷</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>        위노바</td>
#     </tr>
#   </tbody>
# </table>

# %%
import sys
sys.path.append('../../src/main/')
sys.path.append('../../lib/')

# %reload_ext autoreload
# %autoreload 
from stockcore import *
from tradingalgo import *
from data_mani import *

# %run ../../src/main/scrap.py  

# %matplotlib inline
pd.set_option('display.width',500)
import scrap as sc

sctype = 4
textouts = sc.getData(sctype)

results = pd.DataFrame({'title':textouts})
results = results.drop_duplicates('title')
results = results.reset_index()
results = results.drop('index',1)

dbfilename = 'paxnet_03'
tableName = 'paxnet_03'
sc.saveData(results,dbfilename,tableName)

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0  </th>
#       <td>                                  휴맥스</td>
#     </tr>
#     <tr>
#       <th>1  </th>
#       <td>                               스카이라이프</td>
#     </tr>
#     <tr>
#       <th>2  </th>
#       <td>                                 디비케이</td>
#     </tr>
#     <tr>
#       <th>3  </th>
#       <td>                               에프엔씨엔터</td>
#     </tr>
#     <tr>
#       <th>4  </th>
#       <td>                                  빙그레</td>
#     </tr>
#     <tr>
#       <th>5  </th>
#       <td>                               대림B&amp;Co</td>
#     </tr>
#     <tr>
#       <th>6  </th>
#       <td>                                라이온켐텍</td>
#     </tr>
#     <tr>
#       <th>7  </th>
#       <td>                                  이엠넷</td>
#     </tr>
#     <tr>
#       <th>8  </th>
#       <td>                                케이탑리츠</td>
#     </tr>
#     <tr>
#       <th>9  </th>
#       <td>                        '상장 예정' 아시아경제</td>
#     </tr>
#     <tr>
#       <th>10 </th>
#       <td>                                  블루콤</td>
#     </tr>
#     <tr>
#       <th>11 </th>
#       <td>                                 대한항공</td>
#     </tr>
#     <tr>
#       <th>12 </th>
#       <td>                               베이직하우스</td>
#     </tr>
#     <tr>
#       <th>13 </th>
#       <td>                               엑세스바이오</td>
#     </tr>
#     <tr>
#       <th>14 </th>
#       <td>                                  코메론</td>
#     </tr>
#     <tr>
#       <th>15 </th>
#       <td>                                 디엔에프</td>
#     </tr>
#     <tr>
#       <th>16 </th>
#       <td>                                  NEW</td>
#     </tr>
#     <tr>
#       <th>17 </th>
#       <td>                               와이디온라인</td>
#     </tr>
#     <tr>
#       <th>18 </th>
#       <td>                               KG이니시스</td>
#     </tr>
#     <tr>
#       <th>19 </th>
#       <td>                              한국사이버결제</td>
#     </tr>
#     <tr>
#       <th>20 </th>
#       <td>                                비트컴퓨터</td>
#     </tr>
#     <tr>
#       <th>21 </th>
#       <td>                                이지바이오</td>
#     </tr>
#     <tr>
#       <th>22 </th>
#       <td>                                 대한제강</td>
#     </tr>
#     <tr>
#       <th>23 </th>
#       <td>                                 성신양회</td>
#     </tr>
#     <tr>
#       <th>24 </th>
#       <td>                                현대백화점</td>
#     </tr>
#     <tr>
#       <th>25 </th>
#       <td>                                 iMBC</td>
#     </tr>
#     <tr>
#       <th>26 </th>
#       <td>                                 하나투어</td>
#     </tr>
#     <tr>
#       <th>27 </th>
#       <td>                                   풍산</td>
#     </tr>
#     <tr>
#       <th>28 </th>
#       <td>                                  테크윙</td>
#     </tr>
#     <tr>
#       <th>29 </th>
#       <td>                              CJ프레시웨이</td>
#     </tr>
#     <tr>
#       <th>30 </th>
#       <td>                               "AJ렌터카</td>
#     </tr>
#     <tr>
#       <th>31 </th>
#       <td>                                  락앤락</td>
#     </tr>
#     <tr>
#       <th>32 </th>
#       <td>                                삼진엘앤디</td>
#     </tr>
#     <tr>
#       <th>33 </th>
#       <td>                                   톱텍</td>
#     </tr>
#     <tr>
#       <th>34 </th>
#       <td>                                 유아이엘</td>
#     </tr>
#     <tr>
#       <th>35 </th>
#       <td>                                  KMH</td>
#     </tr>
#     <tr>
#       <th>36 </th>
#       <td>                                 키이스트</td>
#     </tr>
#     <tr>
#       <th>37 </th>
#       <td>                                  인바디</td>
#     </tr>
#     <tr>
#       <th>38 </th>
#       <td>                                 디티앤씨</td>
#     </tr>
#     <tr>
#       <th>39 </th>
#       <td>                               SK네트웍스</td>
#     </tr>
#     <tr>
#       <th>40 </th>
#       <td>                                   로엔</td>
#     </tr>
#     <tr>
#       <th>41 </th>
#       <td>                                 팅크웨어</td>
#     </tr>
#     <tr>
#       <th>42 </th>
#       <td>    하반기 분양 수혜·신규 사업 확장…유진기업 '매수'[하나證]</td>
#     </tr>
#     <tr>
#       <th>43 </th>
#       <td>                                삼천당제약</td>
#     </tr>
#     <tr>
#       <th>44 </th>
#       <td>                                선데이토즈</td>
#     </tr>
#     <tr>
#       <th>45 </th>
#       <td>                                 호텔신라</td>
#     </tr>
#     <tr>
#       <th>46 </th>
#       <td>                                 케이씨텍</td>
#     </tr>
#     <tr>
#       <th>47 </th>
#       <td>                                유비벨록스</td>
#     </tr>
#     <tr>
#       <th>48 </th>
#       <td>                                  쇼박스</td>
#     </tr>
#     <tr>
#       <th>49 </th>
#       <td>                                동성홀딩스</td>
#     </tr>
#     <tr>
#       <th>50 </th>
#       <td>                                 영백씨엠</td>
#     </tr>
#     <tr>
#       <th>51 </th>
#       <td>                                하이트진로</td>
#     </tr>
#     <tr>
#       <th>52 </th>
#       <td>                                미래컴퍼니</td>
#     </tr>
#     <tr>
#       <th>53 </th>
#       <td>                                이엠코리아</td>
#     </tr>
#     <tr>
#       <th>54 </th>
#       <td>                                이지웰페어</td>
#     </tr>
#     <tr>
#       <th>55 </th>
#       <td>                              아이마켓코리아</td>
#     </tr>
#     <tr>
#       <th>56 </th>
#       <td>                                 솔브레인</td>
#     </tr>
#     <tr>
#       <th>57 </th>
#       <td>                                 롯데칠성</td>
#     </tr>
#     <tr>
#       <th>58 </th>
#       <td>                                  휴켐스</td>
#     </tr>
#     <tr>
#       <th>59 </th>
#       <td>                                  휴비츠</td>
#     </tr>
#     <tr>
#       <th>60 </th>
#       <td>                                   서흥</td>
#     </tr>
#     <tr>
#       <th>61 </th>
#       <td>                               로체시스템즈</td>
#     </tr>
#     <tr>
#       <th>62 </th>
#       <td>                                 롯데푸드</td>
#     </tr>
#     <tr>
#       <th>63 </th>
#       <td>                               도이치모터스</td>
#     </tr>
#     <tr>
#       <th>64 </th>
#       <td>                                   무학</td>
#     </tr>
#     <tr>
#       <th>65 </th>
#       <td>           올해 실적은 하반기부터…에스엠 '매수'[KB證]</td>
#     </tr>
#     <tr>
#       <th>66 </th>
#       <td>   칵테일 소주 앞세워 수도권 공략 본격화…무학 '매수'[신한金]</td>
#     </tr>
#     <tr>
#       <th>67 </th>
#       <td>                               SIMPAC</td>
#     </tr>
#     <tr>
#       <th>68 </th>
#       <td>          새로운 성장 기대되는 동성화인텍 '매수'[하나證]</td>
#     </tr>
#     <tr>
#       <th>69 </th>
#       <td>                                 슈프리마</td>
#     </tr>
#     <tr>
#       <th>70 </th>
#       <td>                               다산네트웍스</td>
#     </tr>
#     <tr>
#       <th>71 </th>
#       <td>                                농우바이오</td>
#     </tr>
#     <tr>
#       <th>72 </th>
#       <td> 자산운용 분야 차별화된 플레이어 될 것…동양생명 '매수'[NH證]</td>
#     </tr>
#     <tr>
#       <th>73 </th>
#       <td>  2분기 바닥 치고 3분기부터 성장…파라다이스 '매수'[메리츠證]</td>
#     </tr>
#     <tr>
#       <th>74 </th>
#       <td>        기저효과에 제품가격 인상까지…빙그레 '매수'[교보證]</td>
#     </tr>
#     <tr>
#       <th>75 </th>
#       <td>                                 진로발효</td>
#     </tr>
#     <tr>
#       <th>76 </th>
#       <td>                              안정적인 음료</td>
#     </tr>
#     <tr>
#       <th>77 </th>
#       <td>                                 서전기전</td>
#     </tr>
#     <tr>
#       <th>78 </th>
#       <td>                                  녹십자</td>
#     </tr>
#     <tr>
#       <th>79 </th>
#       <td>                                  파트론</td>
#     </tr>
#     <tr>
#       <th>80 </th>
#       <td>                                 쿠쿠전자</td>
#     </tr>
#     <tr>
#       <th>81 </th>
#       <td>                                 큐브엔터</td>
#     </tr>
#     <tr>
#       <th>82 </th>
#       <td>                                 인터파크</td>
#     </tr>
#     <tr>
#       <th>83 </th>
#       <td>                                  SBS</td>
#     </tr>
#     <tr>
#       <th>84 </th>
#       <td>                                레드캡투어</td>
#     </tr>
#     <tr>
#       <th>85 </th>
#       <td>                                  씨큐브</td>
#     </tr>
#     <tr>
#       <th>

# %%
import sys
sys.path.append('../../src/main/')
sys.path.append('../../lib/')

# %reload_ext autoreload
# %autoreload 
from stockcore import *
from tradingalgo import *
from data_mani import *

# %run ../../src/main/scrap.py  

# %matplotlib inline
pd.set_option('display.width',500)
import scrap as sc


sc.saveSumData()
# Out:
# naver_00_20150803.sqlite
# paxnet_00_20150803.sqlite
# paxnet_01_20150803.sqlite
# paxnet_02_20150803.sqlite
# naver_00
# paxnet_00
# paxnet_01
# paxnet_02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0  </th>
#       <td>       코나아이</td>
#     </tr>
#     <tr>
#       <th>1  </th>
#       <td>       오르비텍</td>
#     </tr>
#     <tr>
#       <th>2  </th>
#       <td>     BGF리테일</td>
#     </tr>
#     <tr>
#       <th>3  </th>
#       <td>     한국항공우주</td>
#     </tr>
#     <tr>
#       <th>4  </th>
#       <td>       현대통신</td>
#     </tr>
#     <tr>
#       <th>5  </th>
#       <td>     LG하우시스</td>
#     </tr>
#     <tr>
#       <th>6  </th>
#       <td>     LG유플러스</td>
#     </tr>
#     <tr>
#       <th>7  </th>
#       <td>    한국사이버결제</td>
#     </tr>
#     <tr>
#       <th>8  </th>
#       <td>        KCI</td>
#     </tr>
#     <tr>
#       <th>9  </th>
#       <td>       강원랜드</td>
#     </tr>
#     <tr>
#       <th>10 </th>
#       <td>         디오</td>
#     </tr>
#     <tr>
#       <th>11 </th>
#       <td>         한섬</td>
#     </tr>
#     <tr>
#       <th>12 </th>
#       <td>       한국전력</td>
#     </tr>
#     <tr>
#       <th>13 </th>
#       <td>     LG생활건강</td>
#     </tr>
#     <tr>
#       <th>14 </th>
#       <td>    SKCandC</td>
#     </tr>
#     <tr>
#       <th>15 </th>
#       <td>      엔씨소프트</td>
#     </tr>
#     <tr>
#       <th>16 </th>
#       <td>        현대차</td>
#     </tr>
#     <tr>
#       <th>17 </th>
#       <td>      동부하이텍</td>
#     </tr>
#     <tr>
#       <th>18 </th>
#       <td>         동서</td>
#     </tr>
#     <tr>
#       <th>19 </th>
#       <td>         농심</td>
#     </tr>
#     <tr>
#       <th>20 </th>
#       <td>        MPK</td>
#     </tr>
#     <tr>
#       <th>21 </th>
#       <td>      유비벨록스</td>
#     </tr>
#     <tr>
#       <th>22 </th>
#       <td>     에스앤에스텍</td>
#     </tr>
#     <tr>
#       <th>23 </th>
#       <td>     씨티씨바이오</td>
#     </tr>
#     <tr>
#       <th>24 </th>
#       <td>       현대산업</td>
#     </tr>
#     <tr>
#       <th>25 </th>
#       <td>         한샘</td>
#     </tr>
#     <tr>
#       <th>26 </th>
#       <td>     코오롱글로벌</td>
#     </tr>
#     <tr>
#       <th>27 </th>
#       <td>        이마트</td>
#     </tr>
#     <tr>
#       <th>28 </th>
#       <td>         CJ</td>
#     </tr>
#     <tr>
#       <th>29 </th>
#       <td>        휴비츠</td>
#     </tr>
#     <tr>
#       <th>30 </th>
#       <td>       코스맥스</td>
#     </tr>
#     <tr>
#       <th>31 </th>
#       <td>      현대백화점</td>
#     </tr>
#     <tr>
#       <th>32 </th>
#       <td>        KCC</td>
#     </tr>
#     <tr>
#       <th>33 </th>
#       <td>     KT서브마린</td>
#     </tr>
#     <tr>
#       <th>34 </th>
#       <td>       유한양행</td>
#     </tr>
#     <tr>
#       <th>35 </th>
#       <td>  세이브존IandC</td>
#     </tr>
#     <tr>
#       <th>36 </th>
#       <td>     아모레퍼시픽</td>
#     </tr>
#     <tr>
#       <th>37 </th>
#       <td>     한국금융지주</td>
#     </tr>
#     <tr>
#       <th>38 </th>
#       <td>     JB금융지주</td>
#     </tr>
#     <tr>
#       <th>39 </th>
#       <td>       매일유업</td>
#     </tr>
#     <tr>
#       <th>40 </th>
#       <td>  NHN엔터테인먼트</td>
#     </tr>
#     <tr>
#       <th>41 </th>
#       <td>       삼성화재</td>
#     </tr>
#     <tr>
#       <th>42 </th>
#       <td>      SK케미칼</td>
#     </tr>
#     <tr>
#       <th>43 </th>
#       <td>      동아에스티</td>
#     </tr>
#     <tr>
#       <th>44 </th>
#       <td>       삼성전자</td>
#     </tr>
#     <tr>
#       <th>45 </th>
#       <td>     CJ제일제당</td>
#     </tr>
#     <tr>
#       <th>46 </th>
#       <td>       SOil</td>
#     </tr>
#     <tr>
#       <th>47 </th>
#       <td>      CJCGV</td>
#     </tr>
#     <tr>
#       <th>48 </th>
#       <td>      삼양제넥스</td>
#     </tr>
#     <tr>
#       <th>49 </th>
#       <td>        종근당</td>
#     </tr>
#     <tr>
#       <th>50 </th>
#       <td>       고려아연</td>
#     </tr>
#     <tr>
#       <th>51 </th>
#       <td>      롯데케미칼</td>
#     </tr>
#     <tr>
#       <th>52 </th>
#       <td>        인탑스</td>
#     </tr>
#     <tr>
#       <th>53 </th>
#       <td>     SK하이닉스</td>
#     </tr>
#     <tr>
#       <th>54 </th>
#       <td>       현대제철</td>
#     </tr>
#     <tr>
#       <th>55 </th>
#       <td>      농우바이오</td>
#     </tr>
#     <tr>
#       <th>56 </th>
#       <td>       한미약품</td>
#     </tr>
#     <tr>
#       <th>57 </th>
#       <td>         무학</td>
#     </tr>
#     <tr>
#       <th>58 </th>
#       <td>     롯데하이마트</td>
#     </tr>
#     <tr>
#       <th>59 </th>
#       <td>      바이오랜드</td>
#     </tr>
#     <tr>
#       <th>60 </th>
#       <td>       하나투어</td>
#     </tr>
#     <tr>
#       <th>61 </th>
#       <td>      조광페인트</td>
#     </tr>
#     <tr>
#       <th>62 </th>
#       <td>         대교</td>
#     </tr>
#     <tr>
#       <th>63 </th>
#       <td>     에프엔씨엔터</td>
#     </tr>
#     <tr>
#       <th>64 </th>
#       <td>      AK홀딩스</td>
#     </tr>
#     <tr>
#       <th>65 </th>
#       <td>     KTandG</td>
#     </tr>
#     <tr>
#       <th>66 </th>
#       <td>      신세계푸드</td>
#     </tr>
#     <tr>
#       <th>67 </th>
#       <td>      MDS테크</td>
#     </tr>
#     <tr>
#       <th>68 </th>
#       <td>      현대홈쇼핑</td>
#     </tr>
#     <tr>
#       <th>69 </th>
#       <td>     에리트베이직</td>
#     </tr>
#     <tr>
#       <th>70 </th>
#       <td>      넥센타이어</td>
#     </tr>
#     <tr>
#       <th>71 </th>
#       <td>        에스원</td>
#     </tr>
#     <tr>
#       <th>72 </th>
#       <td>     한글과컴퓨터</td>
#     </tr>
#     <tr>
#       <th>73 </th>
#       <td>        코웨이</td>
#     </tr>
#     <tr>
#       <th>74 </th>
#       <td>       국도화학</td>
#     </tr>
#     <tr>
#       <th>75 </th>
#       <td>     한국정보인증</td>
#     </tr>
#     <tr>
#       <th>76 </th>
#       <td>        오리온</td>
#     </tr>
#     <tr>
#       <th>77 </th>
#       <td>     LG생명과학</td>
#     </tr>
#     <tr>
#       <th>78 </th>
#       <td>       호텔신라</td>
#     </tr>
#     <tr>
#       <th>79 </th>
#       <td>      AP시스템</td>
#     </tr>
#     <tr>
#       <th>80 </th>
#       <td>        네패스</td>
#     </tr>
#     <tr>
#       <th>81 </th>
#       <td>         효성</td>
#     </tr>
#     <tr>
#       <th>82 </th>
#       <td>         E1</td>
#     </tr>
#     <tr>
#       <th>83 </th>
#       <td>      케이피에프</td>
#     </tr>
#     <tr>
#       <th>84 </th>
#       <td>     이코리아리츠</td>
#     </tr>
#     <tr>
#       <th>85 </th>
#       <td>      승화프리텍</td>
#     </tr>
#     <tr>
#       <th>86 </th>
#       <td>       사조해표</td>
#     </tr>
#     <tr>
#       <th>87 </th>
#       <td>     데브시스터즈</td>
#     </tr>
#     <tr>
#       <th>88 </th>
#       <td>        씨큐브</td>
#     </tr>
#     <tr>
#       <th>89 </th>
#       <td>       서원인텍</td>
#     </tr>
#     <tr>
#       <th>90 </th>
#       <td>         대현</td>
#     </tr>
#     <tr>
#       <th>91 </th>
#       <td>       아이원스</td>
#     </tr>
#     <tr>
#       <th>92 </th>
#       <td>     서화정보통신</td>
#     </tr>
#     <tr>
#       <th>93 </th>
#       <td>        뉴인텍</td>
#     </tr>
#     <tr>
#       <th>94 </th>
#       <td>        디젠스</td>
#     </tr>
#     <tr>
#       <th>95 </th>
#       <td>      쎌바이오텍</td>
#     </tr>
#     <tr>
#       <th>96 </th>
#       <td>       메디톡스</td>
#     </tr>
#     <tr>
#       <th>97 </th>
#       <td>       아이리버</td>
#     </tr>
#     <tr>
#       <th>98 </th>
#       <td>      유양디앤유</td>
#     </tr>
#     <tr>
#       <th>99 </th>
#       <td>    삼기오토모티브</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>       금호산업</td>
#     </tr>
#     <tr>
#       <th>101</th>
#       <td>       우리기술</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>       네오티스</td>
#     </tr>
#     <tr>
#       <th>103</th>
#       <td>      세종텔레콤</td>
#     </tr>
#     <tr>
#       <th>104</th>
#       <td>        이니텍</td>
#     </tr>
#     <tr>
#       <th>105</th>
#       <td>       세아제강</td>
#     </tr>
#     <tr>
#       <th>106</th>
#       <td>       용현BM</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>       백광산업</td>
#     </tr>
#     <tr>
#       <th>108</th>
#       <td>     글로벌에스엠</td>
#     </tr>
#     <tr>
#       <th>109</th>
#       <td>      삼양홀딩스</td>
#     </tr>
#     <tr>
#       <th>110</th>
#       <td>       남양유업</td>
#     </tr>
#     <tr>
#       <th>111</th>
#       <td>      엠벤처투자</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>        와이솔</td>
#     </tr>
#     <tr>
#       <th>113</th>
#       <td>      씨에스윈드</td>
#     </tr>
#     <tr>
#       <th>114</th>
#       <td>       대한전선</td>
#     </tr>
#     <tr>
#       <th>115</th>
#       <td>      다음카카오</td>
#     </tr>
#     <tr>
#       <th>116</th>
#       <td>       대우증권</td>
#     </tr>
#     <tr>
#       <th>117</th>
#       <td>       이스타코</td>
#     </tr>
#     <tr>
#       <th>118</th>
#       <td>       이구산업</td>
#     </tr>
#     <tr>
#       <th>119</th>
#       <td>        바른손</td>
#     </tr>
#     <tr>
#       <th>120</th>
#       <td>      메리츠화재
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275 entries, 0 to 274
# Data columns (total 1 columns):
# title    275  non-null values
# dtypes: object(1)

# %%
import sys
sys.path.append('../../src/main/')
sys.path.append('../../lib/')

# %reload_ext autoreload
# %autoreload 
from stockcore import *
from tradingalgo import *
from data_mani import *

# %run ../../src/main/scrap.py  

# %matplotlib inline
pd.set_option('display.width',500)
import scrap_autotest as sc_auto
import scrap as sc
import screen as sr

dbdf = sc.saveSumData()
screendf = sr.screenGetData(dbdf,True)
clear_output()


screendf = screendf[screendf['allslope'] > 0.008]

screendf = screendf[screendf['benchmark'] > 0.1]
screendf = screendf.reset_index()
screendf = screendf.drop('index',1)

print len(screendf)
display(HTML(screendf.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>allslope</th>
#       <th>benchmark</th>
#       <th>title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0  </th>
#       <td> 0.008739</td>
#       <td> 0.404838</td>
#       <td>       코나아이</td>
#     </tr>
#     <tr>
#       <th>1  </th>
#       <td> 0.005207</td>
#       <td> 1.542806</td>
#       <td>       오르비텍</td>
#     </tr>
#     <tr>
#       <th>2  </th>
#       <td> 0.009161</td>
#       <td> 0.940750</td>
#       <td>     한국항공우주</td>
#     </tr>
#     <tr>
#       <th>3  </th>
#       <td> 0.007179</td>
#       <td> 0.875320</td>
#       <td>       현대통신</td>
#     </tr>
#     <tr>
#       <th>4  </th>
#       <td> 0.007911</td>
#       <td> 0.175687</td>
#       <td>     LG하우시스</td>
#     </tr>
#     <tr>
#       <th>5  </th>
#       <td> 0.005087</td>
#       <td> 0.054414</td>
#       <td>     LG유플러스</td>
#     </tr>
#     <tr>
#       <th>6  </th>
#       <td> 0.008501</td>
#       <td> 0.449552</td>
#       <td>    한국사이버결제</td>
#     </tr>
#     <tr>
#       <th>7  </th>
#       <td> 0.004767</td>
#       <td> 0.786489</td>
#       <td>        KCI</td>
#     </tr>
#     <tr>
#       <th>8  </th>
#       <td> 0.002676</td>
#       <td> 0.322183</td>
#       <td>       강원랜드</td>
#     </tr>
#     <tr>
#       <th>9  </th>
#       <td> 0.006963</td>
#       <td> 1.264241</td>
#       <td>         디오</td>
#     </tr>
#     <tr>
#       <th>10 </th>
#       <td> 0.001452</td>
#       <td> 0.248792</td>
#       <td>         한섬</td>
#     </tr>
#     <tr>
#       <th>11 </th>
#       <td> 0.004037</td>
#       <td> 0.225772</td>
#       <td>       한국전력</td>
#     </tr>
#     <tr>
#       <th>12 </th>
#       <td> 0.002519</td>
#       <td> 0.388926</td>
#       <td>     LG생활건강</td>
#     </tr>
#     <tr>
#       <th>13 </th>
#       <td> 0.004346</td>
#       <td> 0.311829</td>
#       <td>    SKCandC</td>
#     </tr>
#     <tr>
#       <th>14 </th>
#       <td> 0.007373</td>
#       <td> 0.253292</td>
#       <td>      엔씨소프트</td>
#     </tr>
#     <tr>
#       <th>15 </th>
#       <td> 0.001146</td>
#       <td>-0.126192</td>
#       <td>        현대차</td>
#     </tr>
#     <tr>
#       <th>16 </th>
#       <td> 0.004105</td>
#       <td> 1.437438</td>
#       <td>      동부하이텍</td>
#     </tr>
#     <tr>
#       <th>17 </th>
#       <td> 0.011448</td>
#       <td> 0.701697</td>
#       <td>         동서</td>
#     </tr>
#     <tr>
#       <th>18 </th>
#       <td> 0.005225</td>
#       <td> 0.265243</td>
#       <td>         농심</td>
#     </tr>
#     <tr>
#       <th>19 </th>
#       <td> 0.002588</td>
#       <td> 0.115348</td>
#       <td>        MPK</td>
#     </tr>
#     <tr>
#       <th>20 </th>
#       <td> 0.000586</td>
#       <td> 0.177982</td>
#       <td>      유비벨록스</td>
#     </tr>
#     <tr>
#       <th>21 </th>
#       <td> 0.003644</td>
#       <td> 1.241696</td>
#       <td>     에스앤에스텍</td>
#     </tr>
#     <tr>
#       <th>22 </th>
#       <td> 0.008440</td>
#       <td> 0.402270</td>
#       <td>     씨티씨바이오</td>
#     </tr>
#     <tr>
#       <th>23 </th>
#       <td> 0.005529</td>
#       <td> 0.660013</td>
#       <td>       현대산업</td>
#     </tr>
#     <tr>
#       <th>24 </th>
#       <td> 0.006863</td>
#       <td> 0.986025</td>
#       <td>         한샘</td>
#     </tr>
#     <tr>
#       <th>25 </th>
#       <td> 0.003179</td>
#       <td> 1.272481</td>
#       <td>     코오롱글로벌</td>
#     </tr>
#     <tr>
#       <th>26 </th>
#       <td> 0.000793</td>
#       <td> 0.165178</td>
#       <td>        이마트</td>
#     </tr>
#     <tr>
#       <th>27 </th>
#       <td> 0.005748</td>
#       <td> 0.719832</td>
#       <td>         CJ</td>
#     </tr>
#     <tr>
#       <th>28 </th>
#       <td> 0.003552</td>
#       <td> 0.341112</td>
#       <td>        휴비츠</td>
#     </tr>
#     <tr>
#       <th>29 </th>
#       <td> 0.000082</td>
#       <td> 0.238827</td>
#       <td>      현대백화점</td>
#     </tr>
#     <tr>
#       <th>30 </th>
#       <td> 0.002044</td>
#       <td>-0.083103</td>
#       <td>        KCC</td>
#     </tr>
#     <tr>
#       <th>31 </th>
#       <td>-0.001184</td>
#       <td>-0.039321</td>
#       <td>     KT서브마린</td>
#     </tr>
#     <tr>
#       <th>32 </th>
#       <td> 0.004409</td>
#       <td> 0.477580</td>
#       <td>       유한양행</td>
#     </tr>
#     <tr>
#       <th>33 </th>
#       <td>-0.000630</td>
#       <td> 0.063454</td>
#       <td>  세이브존IandC</td>
#     </tr>
#     <tr>
#       <th>34 </th>
#       <td> 0.001291</td>
#       <td> 0.614161</td>
#       <td>     아모레퍼시픽</td>
#     </tr>
#     <tr>
#       <th>35 </th>
#       <td>-0.000720</td>
#       <td> 0.286395</td>
#       <td>     한국금융지주</td>
#     </tr>
#     <tr>
#       <th>36 </th>
#       <td>-0.000693</td>
#       <td> 0.076355</td>
#       <td>     JB금융지주</td>
#     </tr>
#     <tr>
#       <th>37 </th>
#       <td> 0.001269</td>
#       <td> 0.044503</td>
#       <td>       매일유업</td>
#     </tr>
#     <tr>
#       <th>38 </th>
#       <td> 0.002668</td>
#       <td>-0.420800</td>
#       <td>  NHN엔터테인먼트</td>
#     </tr>
#     <tr>
#       <th>39 </th>
#       <td>-0.002170</td>
#       <td>-0.045129</td>
#       <td>       삼성화재</td>
#     </tr>
#     <tr>
#       <th>40 </th>
#       <td>-0.000736</td>
#       <td> 0.107821</td>
#       <td>      SK케미칼</td>
#     </tr>
#     <tr>
#       <th>41 </th>
#       <td> 0.002327</td>
#       <td> 0.508244</td>
#       <td>      동아에스티</td>
#     </tr>
#     <tr>
#       <th>42 </th>
#       <td>-0.001087</td>
#       <td>-0.109521</td>
#       <td>       삼성전자</td>
#     </tr>
#     <tr>
#       <th>43 </th>
#       <td> 0.001323</td>
#       <td> 0.349865</td>
#       <td>     CJ제일제당</td>
#     </tr>
#     <tr>
#       <th>44 </th>
#       <td>-0.003745</td>
#       <td> 0.236618</td>
#       <td>       SOil</td>
#     </tr>
#     <tr>
#       <th>45 </th>
#       <td> 0.002660</td>
#       <td> 0.797300</td>
#       <td>      CJCGV</td>
#     </tr>
#     <tr>
#       <th>46 </th>
#       <td>-0.002244</td>
#       <td> 0.786849</td>
#       <td>      삼양제넥스</td>
#     </tr>
#     <tr>
#       <th>47 </th>
#       <td>-0.001377</td>
#       <td> 0.191053</td>
#       <td>       고려아연</td>
#     </tr>
#     <tr>
#       <th>48 </th>
#       <td>-0.001855</td>
#       <td> 0.441125</td>
#       <td>      롯데케미칼</td>
#     </tr>
#     <tr>
#       <th>49 </th>
#       <td>-0.004736</td>
#       <td>-0.025583</td>
#       <td>        인탑스</td>
#     </tr>
#     <tr>
#       <th>50 </th>
#       <td>-0.006507</td>
#       <td>-0.257273</td>
#       <td>     SK하이닉스</td>
#     </tr>
#     <tr>
#       <th>51 </th>
#       <td>-0.004807</td>
#       <td>-0.096355</td>
#       <td>       현대제철</td>
#     </tr>
#     <tr>
#       <th>52 </th>
#       <td>-0.001266</td>
#       <td> 0.009285</td>
#       <td>      농우바이오</td>
#     </tr>
#     <tr>
#       <th>53 </th>
#       <td> 0.003599</td>
#       <td> 1.526007</td>
#       <td>       한미약품</td>
#     </tr>
#     <tr>
#       <th>54 </th>
#       <td> 0.000314</td>
#       <td> 0.423066</td>
#       <td>         무학</td>
#     </tr>
#     <tr>
#       <th>55 </th>
#       <td>-0.004023</td>
#       <td> 0.024014</td>
#       <td>     롯데하이마트</td>
#     </tr>
#     <tr>
#       <th>56 </th>
#       <td>-0.002154</td>
#       <td> 0.572098</td>
#       <td>      바이오랜드</td>
#     </tr>
#     <tr>
#       <th>57 </th>
#       <td> 0.013127</td>
#       <td> 0.861473</td>
#       <td>       하나투어</td>
#     </tr>
#     <tr>
#       <th>58 </th>
#       <td> 0.015649</td>
#       <td> 0.789354</td>
#       <td>      조광페인트</td>
#     </tr>
#     <tr>
#       <th>59 </th>
#       <td> 0.006486</td>
#       <td> 0.344367</td>
#       <td>         대교</td>
#     </tr>
#     <tr>
#       <th>60 </th>
#       <td> 0.006486</td>
#       <td> 0.344367</td>
#       <td>     에프엔씨엔터</td>
#     </tr>
#     <tr>
#       <th>61 </th>
#       <td> 0.005021</td>
#       <td> 0.156173</td>
#       <td>      AK홀딩스</td>
#     </tr>
#     <tr>
#       <th>62 </th>
#       <td> 0.003749</td>
#       <td> 0.368769</td>
#       <td>     KTandG</td>
#     </tr>
#     <tr>
#       <th>63 </th>
#       <td> 0.005115</td>
#       <td> 0.778357</td>
#       <td>      신세계푸드</td>
#     </tr>
#     <tr>
#       <th>64 </th>
#       <td> 0.002048</td>
#       <td> 0.307910</td>
#       <td>      MDS테크</td>
#     </tr>
#     <tr>
#       <th>65 </th>
#       <td>-0.001198</td>
#       <td>-0.058337</td>
#       <td>      현대홈쇼핑</td>
#     </tr>
#     <tr>
#       <th>66 </th>
#       <td> 0.023029</td>
#       <td> 0.795349</td>
#       <td>     에리트베이직</td>
#     </tr>
#     <tr>
#       <th>67 </th>
#       <td> 0.004126</td>
#       <td> 0.144068</td>
#       <td>      넥
