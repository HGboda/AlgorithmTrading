# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../../custom.css", "r").read()
    return HTML(styles)

css_styling()
# Out:
# <style>
#     #notebook_panel { /* main background */
#     background: #333;
#     color: #f6f6f6;
# }
#
# div #notebook { /* centre the content */
#     background: #fff;
#     color: #333;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     padding-top: 2ex;
# }
#
# /* remove big margins around title */
# div.text_cell_render.border-box-sizing.rendered_html {
#     margin: 0;
#     padding: 0;
#     margin-left: 1ex;
# }
# div.cell.text_cell.border-box-sizing {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h1 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h2 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h3 {
#     margin: 0;
#     padding: 0;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 100%;
#
# }
#
# div.cell.code_cell { /* area that contains code + output */
#     background: #fff;
#     border: none;
#     border-radius: 10px;
#     padding-top: 1ex;
#
# }
#
# ...

# %%
import sys
sys.path.append('../../src/main/')
sys.path.append('../../lib/')

# %reload_ext autoreload
# %autoreload 
from stockcore import *
from tradingalgo import *
from data_mani import *
import ver1_8_autotest as v18_auto
# %run ../../src/main/ver1_8_i.py  

# %matplotlib inline
pd.set_option('display.width',500)
# %run ../../src/main/ver1_8_autotest.py
v18_auto.simulAuto(75,100,'analysis_table_3',2)
# Out:
# total run elapsed time: 724.747499908 total runcount: 1
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MACDSig</th>
#       <th>SLOWSig</th>
#       <th>algo1_accumgain</th>
#       <th>algo1_tradinggain</th>
#       <th>algo1_tradingnum</th>
#       <th>benchmark</th>
#       <th>lastDate</th>
#       <th>stance</th>
#       <th>title</th>
#       <th>totalsum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0 </th>
#       <td> 1</td>
#       <td> 1</td>
#       <td>-0.010095</td>
#       <td>-0.010061</td>
#       <td> 3</td>
#       <td> 0.297075</td>
#       <td> 2015-05-28 00:00:00</td>
#       <td> none</td>
#       <td>      크레듀</td>
#       <td>  9823600</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td> 1</td>
#       <td> 1</td>
#       <td>-0.194944</td>
#       <td>-0.195121</td>
#       <td> 3</td>
#       <td> 0.137437</td>
#       <td> 2015-04-13 00:00:00</td>
# ...

# %%
import sys
sys.path.append('../../src/main/')
sys.path.append('../../lib/')

# %reload_ext autoreload
# %autoreload 
from stockcore import *
from tradingalgo import *
from data_mani import *
# %run ../../src/main/ver1_8_i.py  

# %matplotlib inline
pd.set_option('display.width',500)
# %run ../../src/main/db_analysis.py

# %%
# %run ../../src/main/plotlychart.py
