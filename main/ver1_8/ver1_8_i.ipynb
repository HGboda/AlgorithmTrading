# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../../custom.css", "r").read()
    return HTML(styles)

css_styling()
# Out:
# <style>
#     #notebook_panel { /* main background */
#     background: #333;
#     color: #f6f6f6;
# }
#
# div #notebook { /* centre the content */
#     background: #fff;
#     color: #333;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     padding-top: 2ex;
# }
#
# /* remove big margins around title */
# div.text_cell_render.border-box-sizing.rendered_html {
#     margin: 0;
#     padding: 0;
#     margin-left: 1ex;
# }
# div.cell.text_cell.border-box-sizing {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h1 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h2 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h3 {
#     margin: 0;
#     padding: 0;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 100%;
#
# }
#
# div.cell.code_cell { /* area that contains code + output */
#     background: #fff;
#     border: none;
#     border-radius: 10px;
#     padding-top: 1ex;
#
# }
#
# ...

# %%
import sys
sys.path.append('../../src/main/')
sys.path.append('../../lib/')

# %reload_ext autoreload
# %autoreload 
from stockcore import *
from tradingalgo import *
from data_mani import *
# %run ../../src/main/ver1_8_i.py  

# %matplotlib inline
pd.set_option('display.width',500)
# %run ../../src/main/i_widget.py
# Out:
# KCC
# 002380 KCC
# Run: 002380 KCC
# none
# appenddb
# appenddb
# _inRunSimul
# stdarg stddb smallarg none dayselect 0 tangentmode tangentdb
# startdate 2013-01-01
# GOOG/KRX_002380 KCC realtime none 2013-01-01
# ---------
# ----date adjust start---
# ----date adjust end-----
# fetch real data return
# http://finance.yahoo.com/d/quotes.csv?s=002380.KS&f=sl1d1t1c1ohgv&e=.csv
# rtsymbol:
#  002380.KS rtclose: 508000.0 6/8/2015 3:00pm -3000.0 rtopen: 515000.0 rthigh: 522000.0 rtlow: 508000.0 rtvolume: 29023.0
#              Close    High     Low    Open  Volume
# Date
# 2015-06-08  508000  522000  508000  515000   29023 True
# ----------
# ----------final sorted bars---------
#              Close    High     Low    Open  Volume
# Date
# 2015-06-02  527000  545000  519000  540000   32946
# 2015-06-03  516000  527000  516000  522000   24425
# 2015-06-04  514000  523000  513000  520000   26313
# 2015-06-05  511000  518000  507000  513000   21159
# ...

# %%
print 1.91672834e+09
# Out:
# 1916728340.0

# %%
import talib
import ver1_8_i as v18
v18.gbars2 
bars = v18.gbars2
macd, macdsignal, macdhist = talib.MACD(bars['Close'].values, 12, 26, 9)
# print macdsignal

# %%
# %run ../../src/main/plotlychart.py
